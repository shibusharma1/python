# %%
# pip install mysql-connector-python

# %%
import mysql.connector # Connect to the MySQL database
conn = mysql.connector.connect(
    user='root',   
    password='',   
    host='localhost'
)
# Create a cursor object 
cursor = conn.cursor() # Create a new database
query = "CREATE DATABASE bimp"
cursor.execute(query)# Use the new database
query = "USE bimp" 
cursor.execute(query)# Create a new table
query = """
    CREATE TABLE users (
        id INT AUTO_INCREMENT,
        name VARCHAR(255),
        address VARCHAR(255),
        PRIMARY KEY (id)
    )
"""
cursor.execute(query)# Commit the changes
conn.commit()# Close the cursor and connection
cursor.close() 
conn.close()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\shibu\OneDrive\Desktop\python\python\DB\venv\Lib\site-packages\mysql\connector\connection_cext.py:334, in CMySQLConnection._open_connection(self)
#     333 try:
# --> 334     self._cmysql.connect(**cnx_kwargs)
#     335     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (10061)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[9], line 2
#       1 import mysql.connector # Connect to the MySQL database
# ----> 2 conn = mysql.connector.connect(
#       3     user='root',
#       4     password='',
#       5     host='localhost'
#       6 )
#       7 # Create a cursor object
# ...

# %%
import mysql.connector

# Connect to the MySQL database
cnx = mysql.connector.connect(
    user='root',
    password='password',
    host='localhost'
)

# Create a cursor object
cursor = cnx.cursor()

# Use the new database
query = "USE bimp"
cursor.execute(query)

# Insert a new record
query = "INSERT INTO users (name, address) VALUES (%s, %s)"
values = ('Ram', 'Biratnagar')
cursor.execute(query, values)

# values = [('Shyam', 'Dharan'),('Hari', 'Itahari')]
# cursor.executemany(query, values)

# Commit the changes
cnx.commit()

# Close the cursor and connection
cursor.close()
cnx.close()

# %%
import mysql.connector

# Connect to the MySQL database
cnx = mysql.connector.connect(
    user='root',
    password='password',
    host='localhost'
)

# Create a cursor object
cursor = cnx.cursor()

# Use the new database
query = "USE bimp"
cursor.execute(query)

# Create a cursor object
cursor = cnx.cursor()

# Retrieve all records from the table
query = "SELECT * FROM users"
cursor.execute(query)

# Fetch all the rows
rows = cursor.fetchall()

# Print the results
for row in rows:
    print(row)

# Close the cursor and connection
cursor.close()
cnx.close()

# %%
import mysql.connector

# Connect to the MySQL database
cnx = mysql.connector.connect(
    user='root',
    password='password',
    host='localhost',
    database='bimp'
)

# Create a cursor object
cursor = cnx.cursor()

# Update a record
query = "UPDATE users SET name = %s, address = %s WHERE id = %s"
values = ('Shyam', 'Dharan', 1)
cursor.execute(query, values)

# Commit the changes
cnx.commit()

# Close the cursor and connection
cursor.close()
cnx.close()

# %%
# Connect to the MySQL database
cnx = mysql.connector.connect(
    user='root',
    password='password',
    host='localhost',
    database='bimp'
)

# Create a cursor object
cursor = cnx.cursor()

# # Delete a record
# query = "DELETE FROM users WHERE id = %s"
# values = [1]
# cursor.execute(query, values)

# # Delete multiple records
# query = "DELETE FROM users WHERE id IN (%s, %s)"
# values = (2, 3)
# cursor.execute(query, values)

# Delete multiple records
query = "DELETE FROM users WHERE id = %s"
values = [(4,),]
cursor.executemany(query, values)

# Commit the changes
cnx.commit()

# Close the cursor and connection
cursor.close()
cnx.close()
